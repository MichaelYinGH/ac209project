# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
convert={'Date': lambda x: pd.to_datetime(x)}
restriction_raw = pd.read_csv("../raw_data/OxCGRT_US_latest.csv", low_memory=False, converters = convert)

# %%
restriction_raw
# Out:
#          CountryName CountryCode RegionName RegionCode Jurisdiction  \
# 0      United States         USA        NaN        NaN      NAT_GOV
# 1      United States         USA        NaN        NaN      NAT_GOV
# 2      United States         USA        NaN        NaN      NAT_GOV
# 3      United States         USA        NaN        NaN      NAT_GOV
# 4      United States         USA        NaN        NaN      NAT_GOV
# ...              ...         ...        ...        ...          ...
# 18174  United States         USA    Wyoming      US_WY   STATE_WIDE
# 18175  United States         USA    Wyoming      US_WY   STATE_WIDE
# 18176  United States         USA    Wyoming      US_WY   STATE_WIDE
# 18177  United States         USA    Wyoming      US_WY   STATE_WIDE
# 18178  United States         USA    Wyoming      US_WY   STATE_WIDE
#
#             Date  C1_School closing  C1_Flag C1_Notes  C2_Workplace closing  \
# ...

# %%
restriction_df = restriction_raw[["RegionName","Date","C4_Restrictions on gatherings","C6_Stay at home requirements","StringencyIndex"]]
# restriction_df.dropna(inplace = True)
# gather_dummies = pd.get_dummies(restriction_df["C4_Restrictions on gatherings"], prefix="gather", prefix_sep='_')
# home_dummies = pd.get_dummies(restriction_df["C6_Stay at home requirements"], prefix="home", prefix_sep='_')

# restriction_out = pd.concat([restriction_df, gather_dummies, home_dummies], axis = 1)
# restriction_out.drop(["C4_Restrictions on gatherings","C6_Stay at home requirements"], axis = 1, inplace = True)

restriction_df
# Out:
#       RegionName       Date  C4_Restrictions on gatherings  \
# 0            NaN 2020-01-01                            0.0
# 1            NaN 2020-01-02                            0.0
# 2            NaN 2020-01-03                            0.0
# 3            NaN 2020-01-04                            0.0
# 4            NaN 2020-01-05                            0.0
# ...          ...        ...                            ...
# 18174    Wyoming 2020-12-04                            3.0
# 18175    Wyoming 2020-12-05                            3.0
# 18176    Wyoming 2020-12-06                            3.0
# 18177    Wyoming 2020-12-07                            NaN
# 18178    Wyoming 2020-12-08                            NaN
#
#        C6_Stay at home requirements  StringencyIndex
# 0                               0.0             0.00
# 1                               0.0             0.00
# 2                               0.0             0.00
# ...

# %%
restriction_df.to_csv("../processed_data/restriction.csv", index = False)
